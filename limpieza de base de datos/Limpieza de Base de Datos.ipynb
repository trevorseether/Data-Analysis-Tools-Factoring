# %%
import pandas as pd

# !pip install pyathena
from pyathena import connect

import json
# Out:
# Requirement already satisfied: pyathena in /usr/local/lib/python3.12/dist-packages (3.27.2)
# Requirement already satisfied: boto3>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from pyathena) (1.42.50)
# Requirement already satisfied: botocore>=1.29.4 in /usr/local/lib/python3.12/dist-packages (from pyathena) (1.42.50)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from pyathena) (2025.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from pyathena) (2.9.0.post0)
# Requirement already satisfied: tenacity>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from pyathena) (9.1.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.26.4->pyathena) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.26.4->pyathena) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore>=1.29.4->pyathena) (2.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->pyathena) (1.17.0)

# %%
from datetime import datetime, timedelta
hoy = datetime.now()             # timestamp actual
hace_2_semanas = hoy - timedelta(weeks=2)

print("Hoy:", hoy)
print("Hace 2 semanas:", hace_2_semanas)

ymd_2_semanas = hace_2_semanas.strftime("%Y-%m-%d")
print(ymd_2_semanas)
# Out:
# Hoy: 2026-02-16 21:20:28.371700
# Hace 2 semanas: 2026-02-02 21:20:28.371700
# 2026-02-02

# %%
# Colores ANSI
class C:
    RED     = '\033[91m'
    GREEN   = '\033[92m'
    YELLOW  = '\033[93m'
    BLUE    = '\033[94m'
    BOLD    = '\033[1m'
    END     = '\033[0m'
    ORANGE  = '\033[38;5;208m'   # Naranja (256-colors)


# print(f"{C.BOLD}{C.BLUE}=== INFORME MENSUAL ==={C.END}")
# print(f"{C.BLUE}=== INFORME MENSUAL ==={C.END}")
# print(f"{C.GREEN}✔ Procesado correctamente{C.END}")
# print(f"{C.YELLOW}⚠ Advertencia: valores faltantes detectados{C.END}")
# print(f"{C.RED}✘ Error en la carga de datos{C.END}")

# %%
#%% Credenciales de AmazonAthena

with open(r"/content/credenciales actualizado.txt") as f:
    creds = json.load(f)

conn = connect(
    aws_access_key_id     = creds["AccessKeyId"],
    aws_secret_access_key = creds["SecretAccessKey"],
    aws_session_token     = creds["SessionToken"],
    s3_staging_dir        = creds["s3_staging_dir"],
    region_name           = creds["region_name"]

    )

# %%
# Moneda de la operación distinta en fac_requests y hubspot__deal

query ='''
with moneda_fr as  (

SELECT
    FR.CODE,
    FR.proforma_simulation_currency as moneda_fr

FROM prod_datalake_analytics.FAC_REQUESTS AS FR
where FR.status not in ('rejected', 'canceled')

),

moneda_hd as (

select
    dealname,
    moneda_del_monto_financiado as moneda_hd
from prod_datalake_master.hubspot__deal
where pipeline = '14026011'
and dealstage not in ('14026016', '14026018', '1105313628')

)

select
    fr.code,
    fr.moneda_fr,
    hd.moneda_hd

from moneda_fr as fr
left join moneda_hd as hd
on lower(fr.code) = lower(hd.dealname)
where fr.moneda_fr <> hd.moneda_hd

'''

cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
df_moneda = pd.DataFrame(resultados, columns = column_names)

# %%
# RUCs de proveedor o deudor que acaban en “.com”

query ='''
select
    dealname,
    ruc_proveedor,
    ruc_cliente

from prod_datalake_master.hubspot__deal

where pipeline = '14026011'
and lower(ruc_proveedor) like lower('%.com%')
or lower(ruc_cliente) like lower('%.com%')

'''

cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
df_rucs_dotcom = pd.DataFrame(resultados, columns = column_names)

# %%
# Casos urgente de fechas de desembolso diferentes entre Hubspot y Fac_requests, porque cambian el mes

query ='''
with fechas_desembolso_request as (

select
    code,
     cast ( date_add('hour', -5, interest_proforma_disbursement_date)  as date) as f_desembolso
from prod_datalake_analytics.fac_requests
where status not in ('rejected', 'canceled')

), fechas_desembolso_hubspot as (

select
    dealname as code,
    fecha_de_desembolso__factoring_ as f_desembolso
from prod_datalake_master.hubspot__deal
where pipeline = '14026011'
and dealstage not in ('14026016', '14026018', '1105313628')

)
select
    fdr.code,
    fdr.f_desembolso as f_desembolso_request,
    fdh.f_desembolso as f_desembolso_hubspot

from  fechas_desembolso_request as fdr
left join fechas_desembolso_hubspot as fdh
on lower(fdr.code) = lower(fdh.code)

where date_format(fdr.f_desembolso, '%Y%m') <> date_format(fdh.f_desembolso, '%Y%m')
and fdr.f_desembolso >= date '2025-01-01'

order by fdr.f_desembolso desc

'''

cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
df_fecha_desembolso = pd.DataFrame(resultados, columns = column_names)

# %%
# Subasta Activa, más de 2 semanas sin cambios:

query =f'''
select
    dealname,
    fecha_de_desembolso__factoring_,
    'Subasta Activa' as etapa_negocio
from prod_datalake_master.hubspot__deal
where dealstage = '14026014'
and fecha_de_desembolso__factoring_ is not null
and fecha_de_desembolso__factoring_ < date '{ymd_2_semanas}'
order by fecha_de_desembolso__factoring_

'''

cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
df_s_activa = pd.DataFrame(resultados, columns = column_names)

# %%
# Información de Subasta Pendiente, más de 2 semanas sin cambios:

query =f'''
select
    dealname,
    fecha_de_desembolso__factoring_,
    'Información de Subasta pendiente' as etapa_negocio
from prod_datalake_master.hubspot__deal
where dealstage = '14026013'
and fecha_de_desembolso__factoring_ is not null
and fecha_de_desembolso__factoring_ < date '{ymd_2_semanas}'
order by fecha_de_desembolso__factoring_

'''

cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
df_info_pendiente = pd.DataFrame(resultados, columns = column_names)

# %%
# Operaciones hijas que NO heredan la tipificación operativa de adelanto (incluye clones del admin)

query = '''
with adelantos_hubspot as (

select -- adelantos originales
    dealname as code,
    tipificacion_operativa,
    confirmaron_todas_las_facturas_en_cavali_
from prod_datalake_master.hubspot__deal
where pipeline = '14026011'
and tipificacion_operativa = 'Adelanto'

), ops_admin as (

select
    fr.code,
    fr.parent_code,
    ah.tipificacion_operativa,
    ah.confirmaron_todas_las_facturas_en_cavali_

from prod_datalake_analytics.fac_requests as fr
left join adelantos_hubspot as ah
on trim(lower(ah.code)) = trim(lower(fr.parent_code))
where fr.status not in ('rejected', 'canceled')
and fr.parent_code is not null
and ah.tipificacion_operativa is not null

), ops_hijas_hubspot as (

select
    hd.dealname as code,
    hd.codigo_de_subasta,
    ah.tipificacion_operativa,
    ah.confirmaron_todas_las_facturas_en_cavali_

from prod_datalake_master.hubspot__deal as hd
left join adelantos_hubspot as ah
on trim(lower(ah.code)) = trim(lower(hd.codigo_de_subasta))
where hd.pipeline = '14026011'
and ah.tipificacion_operativa is not null

), union_all_1 as (

select code, tipificacion_operativa, confirmaron_todas_las_facturas_en_cavali_ from adelantos_hubspot
union all
select oa.code, oa.tipificacion_operativa, oa.confirmaron_todas_las_facturas_en_cavali_ from ops_admin as oa
left join adelantos_hubspot as ah on trim(lower(ah.code)) = trim(lower(oa.code))
where ah.code is null

), union_all_2 as (

select code, tipificacion_operativa, confirmaron_todas_las_facturas_en_cavali_ from  union_all_1
union all
select hij.code, hij.tipificacion_operativa, hij.confirmaron_todas_las_facturas_en_cavali_ from ops_hijas_hubspot as hij
left join  union_all_1 as ua1 on trim(lower(ua1.code)) = trim(lower(hij.code))
where ua1.code is null

)select
    hd.dealname,
    hd.tipificacion_operativa,
    ua2.tipificacion_operativa as tipificacion_madre
from prod_datalake_master.hubspot__deal AS HD
left join union_all_2 AS UA2
on trim(lower(ua2.code)) = trim(lower(hd.dealname))

where hd.tipificacion_operativa is null
and ua2.tipificacion_operativa is not null
and hd.dealstage not in ('14026016', '14026018')

'''
cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
df_sin_adelanto = pd.DataFrame(resultados, columns = column_names)

# %%
# operaciones clones que tienen el mismo monto financiado que la madre
query = '''
select
    fr.code as code_clon,
    fr.proforma_simulation_financing_total as monto_financiado_hijo,
    fr.parent_code,
    fr2.proforma_simulation_financing_total as monto_financiado_madre,
    fr.proforma_simulation_financing_total - fr2.proforma_simulation_financing_total as alerta,
    coalesce(fr.interest_proforma_disbursement_date, fr2.interest_proforma_disbursement_date, HD.fecha_de_desembolso__factoring_, HD2.fecha_de_desembolso__factoring_, fr.proforma_disbursement_date, fr2.proforma_disbursement_date) as fecha_desembolso,
    fr2.interest_proforma_disbursement_date as fecha_desembolso_madre
from prod_datalake_analytics.fac_requests as fr
left join prod_datalake_analytics.fac_requests as fr2
on fr.parent_code = fr2.code
left join (select * from prod_datalake_master.HUBSPOT__DEAL where pipeline = '14026011' AND dealstage NOT IN ('14026016', '14026018')) AS HD
ON HD.DEALNAME = FR.CODE
left join (select * from prod_datalake_master.HUBSPOT__DEAL where pipeline = '14026011' AND dealstage NOT IN ('14026016', '14026018')) AS HD2
ON HD2.DEALNAME = FR.PARENT_CODE

where fr.parent_code is not null
and fr.status not in ('rejected', 'canceled')
and fr.proforma_simulation_financing_total - fr2.proforma_simulation_financing_total between -10 and 10
--and fr.parent_code = 'XFbWBr84'

order by fr.parent_code


'''

cursor = conn.cursor()
cursor.execute(query)

# Obtener los resultados
resultados = cursor.fetchall()

# Obtener los nombres de las columnas
column_names = [desc[0] for desc in cursor.description]

# Convertir los resultados a un DataFrame de pandas
clones_mal_m_financiado = pd.DataFrame(resultados, columns = column_names)

# %%
print(f"{C.BOLD}{C.GREEN}✔ INFORME DE ALERTAS DETECTADAS:{C.END}")
print(f"=============================================================\n")
if df_moneda.shape[0] == 0:
  print(f"{C.GREEN}✔ Sin diferencias entre monedas{C.END}")
else:
  print(f"{C.ORANGE}⚠ Advertencia: Diferencia entre monedas{C.END}")
  print(df_moneda)
print(f"=============================================================\n")
if df_rucs_dotcom.shape[0] == 0:
  print(f"{C.GREEN}✔ Rucs correctos{C.END}")
else:
  print(f"{C.YELLOW}⚠ Advertencia: Formato de rucs incorrecto, corregir en Hubspot{C.END}")
  print(df_rucs_dotcom)
print(f"=============================================================\n")
if df_fecha_desembolso.shape[0] == 0:
  print(f"{C.GREEN}✔ Sin diferencias relevantes entre fechas de desembolso")
else:
  print(f"{C.RED}⚠ Advertencia verificar: Diferencia entre fechas de desembolso{C.END}")
  print(df_fecha_desembolso)
print(f"=============================================================\n")
if df_s_activa.shape[0] == 0:
  print(f"{C.GREEN}✔ Sin subastas activas más de 2 semanas{C.END}")
else:
  print(f"{C.YELLOW}⚠ Advertencia: Consultar subasta en operaciones, no debería estar activa tanto tiempo{C.END}")
  print(df_s_activa)
print(f"=============================================================\n")
if df_info_pendiente.shape[0] == 0:
  print(f"{C.GREEN}✔ Sin Subastas con información pendiente más de 2 semanas{C.END}")
else:
  print(f"{C.YELLOW}⚠ Advertencia: Consultar subasta en operaciones, no debería estar con información pendiente tanto tiempo{C.END}")
  print(df_info_pendiente)
print(f"=============================================================\n")
if df_sin_adelanto.shape[0] == 0:
  print(f"{C.GREEN}✔ Adelantos de ops hijos correctamente llenados{C.END}")
else:
  print(f"{C.YELLOW}⚠ Advertencia: Existen ops hijas que no han heredado la tipificación de Adelanto{C.END}")
  print(df_sin_adelanto)
print(f"=============================================================\n")
if clones_mal_m_financiado.shape[0] == 0:
  print(f"{C.GREEN}✔ Monto financiado de los clones bien llenados{C.END}")
else:
  print(f"{C.YELLOW}⚠ Advertencia: Existen clones que tienen el mismo monto financiado que la madre{C.END}")
  print(df_sin_adelanto)
print(f"=============================================================\n")
# Out:
# ✔ INFORME DE ALERTAS DETECTADAS:
# =============================================================
#
# ⚠ Advertencia: Diferencia entre monedas
#        code moneda_fr moneda_hd
# 0  yQb0mbHC       USD       PEN
# 1  u0BYubI7       PEN       USD
# 2  LEy90TxT       USD       PEN
# =============================================================
#
# ✔ Rucs correctos
# =============================================================
#
# ⚠ Advertencia verificar: Diferencia entre fechas de desembolso
#         code f_desembolso_request f_desembolso_hubspot
# 0   jnzb7oH0           2026-01-31           2026-02-02
# 1   CS9HdpEL           2025-12-31           2026-01-07
# 2   OsEqqQck           2025-12-31           2026-01-02
# 3   wsyfYkaQ           2025-12-31           2026-01-09
# 4   obd3LisK           2025-12-31           2026-01-09
# 5   BuA39jNU           2025-12-26           2026-01-09
# 6   pa03ALvO           2025-12-24           2026-01-09
# 7   TagsX7jl           2025-12-23           2026-01-09
# 8   pIUt3QVU           2025-12-15           2026-01-09
# 9   kIl6eI0Z           2025-11-29           2025-12-01
# 10  5XqCWHUh           2025-11-27           2025-12-10
# 11  1yV0Hm8J           2025-11-27           2025-12-03
# 12  0UTw0iKx           2025-10-31           2025-11-03
# 13  7I1F0WOf           2025-10-09           2025-11-03
# 14  hZ8fuGEQ           2025-10-02           2025-09-12
# 15  NfqO9FzT           2025-10-02           2025-09-12
# 16  oFRS0Tjs           2025-09-30           2025-10-06
# 17  YkbPeN0q           2025-09-22           2025-08-22
# 18  iDvsQp0h           2025-08-29           2025-09-03
# 19  itw43mSi           2025-08-29           2025-09-29
# 20  wYq7OsP3           2025-08-29           2025-09-03
# 21  r5oHheUw           2025-08-25           2025-09-02
# 22  7RgNnwlY           2025-08-22           2025-09-01
# 23  hKF65IAq           2025-07-31           2025-08-13
# 24  QbLGAyr4           2025-07-30           2025-08-04
# 25  pLp0ZXWS           2025-07-25           2025-08-12
# 26  HR59hpWQ           2025-07-10           2025-08-12
# 27  wdNZxkXI           2025-07-10           2025-08-12
# 28  f2Y29mKI           2025-07-03           2025-08-14
# 29  jcYYVJy0           2025-07-01           2025-06-30
# 30  SyG36OKX           2025-06-16           2025-07-16
# 31  Av8QbxS5           2025-06-10           2025-07-10
# 32  gi0bly73           2025-05-02           2025-04-30
# 33  CWaPymvT           2025-03-20           2025-04-03
# 34  UFQ0iS6g           2025-02-27           2025-03-05
# 35  EO0jadUj           2025-02-20           2025-01-20
# 36  cfkqERKg           2025-02-13           2025-01-28
# 37  2wpDQ7Tu           2025-02-13           2025-01-28
# 38  2ISMGwil           2025-02-13           2025-01-28
# 39  mmnghh0o           2025-01-31           2025-02-03
# 40  0fUIT3e6           2025-01-31           2025-02-07
# 41  pI0OVaiO           2025-01-31           2025-02-01
# 42  cvkTdCsm           2025-01-31           2025-02-05
# 43  AVYCXw61           2025-01-30           2024-12-30
# =============================================================
#
# ✔ Sin subastas activas más de 2 semanas
# =============================================================
#
# ⚠ Advertencia: Consultar subasta en operaciones, no debería estar con información pendiente tanto tiempo
#    dealname fecha_de_desembolso__factoring_                     etapa_negocio
# 0  f6uTTzbJ                      2025-09-03  Información de Subasta pendiente
# 1  1WEFJe6K                      2026-01-21  Información de Subasta pendiente
# =============================================================
#
# ⚠ Advertencia: Existen ops hijas que no han heredado la tipificación de Adelanto
#        dealname tipificacion_operativa tipificacion_operativa
# 0      QmLS3oYY                   None               Adelanto
# 1  ejdCWo2C - 1                   None               Adelanto
# 2      0gj9vBvp                   None               Adelanto
# 3  WJevRaCQ - 1                   None               Adelanto
# =============================================================
#
# ✔ Monto financiado de los clones bien llenados
# =============================================================
